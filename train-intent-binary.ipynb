# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0032.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0026.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0040.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0056.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0009.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0011.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0018.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0005.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0051.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0014.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0020.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0041.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0055.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0000.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0038.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0009.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0000.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0020.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0037.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0043.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0019.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0001.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0047.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0022.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0006.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0017.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0030.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0003.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0012.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0024.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0002.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0010.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0056.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0031.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0008.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0002.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0036.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0021.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0054.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0006.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0050.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0036.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0035.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0054.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0034.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0022.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0018.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0021.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0047.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0005.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0013.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0032.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0007.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0023.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0025.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0049.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0055.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0053.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0051.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0040.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0029.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0016.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0033.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0048.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0042.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0015.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0052.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0019.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0026.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0031.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0003.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0001.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0042.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0025.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0048.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0052.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0038.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0039.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0041.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0004.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0013.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0034.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0028.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0044.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0004.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0035.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0043.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0015.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0007.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0030.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0011.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0012.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0010.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0024.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0029.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0045.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0017.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0046.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0027.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0027.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0037.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0050.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0028.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0045.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0016.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0033.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0046.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0053.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0023.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0049.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0014.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0044.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0039.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0008.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0032.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0049.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0025.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0046.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0032.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0036.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0011.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0040.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0040.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0050.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0014.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0056.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0009.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0039.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0025.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0030.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0005.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0018.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0009.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0051.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0031.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0033.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0000.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0011.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0002.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0042.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0008.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0007.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0027.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0016.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0037.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0038.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0021.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0041.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0037.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0016.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0000.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0005.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0026.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0022.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0020.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0020.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0049.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0003.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0050.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0004.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0020.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0022.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0041.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0001.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0015.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0027.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0043.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0054.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0042.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0014.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0004.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0047.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0043.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0013.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0049.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0024.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0006.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0008.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0026.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0056.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0044.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0047.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0030.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0003.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0024.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0002.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0015.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0044.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0051.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0039.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0040.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0031.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0001.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0021.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0054.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0041.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0036.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0006.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0043.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0056.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0031.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0029.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0048.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0001.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0039.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0022.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0045.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0018.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0038.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0034.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0012.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0029.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0048.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0010.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0054.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0012.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0017.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0007.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0017.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0040.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0002.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0024.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0027.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0049.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0055.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0009.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0055.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0032.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0051.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0056.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0014.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0006.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0045.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0010.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0000.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0051.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0029.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0052.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0033.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0033.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0035.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0028.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0030.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0042.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0015.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0006.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0052.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0055.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0019.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0023.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0026.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0001.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0054.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0031.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0025.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0048.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0024.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0021.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0004.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0050.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0013.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0007.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0034.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0038.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0016.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0028.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0000.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0020.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0037.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0005.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0044.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0047.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0013.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0052.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0004.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0023.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0019.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0029.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0013.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0010.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0055.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0046.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0011.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0034.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0053.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0052.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0046.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0012.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0026.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0028.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0003.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0015.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0008.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0035.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0053.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0048.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0022.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0030.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0009.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0033.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0028.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0032.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0011.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0047.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0053.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0041.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0012.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0018.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0036.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0036.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0010.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0045.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0002.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0017.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0038.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0027.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0043.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0037.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0050.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0034.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0016.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0021.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0019.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0035.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0045.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0046.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0053.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0007.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0019.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0005.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0023.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0017.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qlabel_0035.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0014.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0023.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0044.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0039.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0042.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0003.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/Qscore_0025.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/X_0008.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/quality_dataset/meta_0018.json
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0017.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0011.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0025.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0019.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0006.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0012.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0011.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0015.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0026.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0018.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0010.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0031.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0021.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0029.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0002.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0008.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0007.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0027.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0023.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0021.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0001.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0026.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0010.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0003.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0004.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0025.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0001.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0024.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0021.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0018.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0024.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0012.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0020.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0005.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0015.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0020.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0009.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0024.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0004.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0023.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0031.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0031.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0022.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0001.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0029.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0003.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0004.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0007.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0009.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0010.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0017.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0009.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0005.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0014.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0006.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0028.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0028.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0030.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0029.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0028.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0016.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0013.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0014.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0002.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0013.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0019.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0013.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0016.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0000.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0026.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0007.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0020.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0018.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0000.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0017.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0011.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0003.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0014.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0000.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0012.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0022.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0030.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0008.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0002.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0030.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0016.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0008.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0022.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0019.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0005.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0023.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0027.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xcorr_0006.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0015.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Qscore_0025.npy
# /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/restoration_dataset/Xclean_0027.npy

# %%
import os
import glob
import time
import copy
import random
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

ROOT = "/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2"
IDIR = os.path.join(ROOT, "intent_dataset")

SEED = 123
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

X_files = sorted(glob.glob(os.path.join(IDIR, "X_*.npy")))
Y_files = sorted(glob.glob(os.path.join(IDIR, "Y_*.npy")))

print("IDIR:", IDIR)
print("shards X:", len(X_files))
print("shards Y:", len(Y_files))
print("Ejemplo X:", X_files[:3])
print("Ejemplo Y:", Y_files[:3])

if len(X_files) == 0 or len(Y_files) == 0:
    raise FileNotFoundError(f"No se encontraron shards en {IDIR}")
# Out:
# IDIR: /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset
# shards X: 57
# shards Y: 57
# Ejemplo X: ['/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0000.npy', '/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0001.npy', '/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0002.npy']
# Ejemplo Y: ['/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0000.npy', '/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0001.npy', '/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0002.npy']

# %%
x0 = np.load(X_files[0], mmap_mode="r")
y0 = np.load(Y_files[0], mmap_mode="r")

print(x0.shape, x0.dtype)
print(y0.shape, y0.dtype)
print("pos frac shard0:", y0.mean())
# Out:
# (20000, 1, 400) float32
# (20000,) float32
# pos frac shard0: 0.40845

# %%
# =========================
# CELDA 1: Dataset + utils
# =========================
import os
import glob
import time
import copy
import random
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

ROOT = "/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2"
IDIR = os.path.join(ROOT, "intent_dataset")

SEED = 123
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

X_files = sorted(glob.glob(os.path.join(IDIR, "X_*.npy")))
Y_files = sorted(glob.glob(os.path.join(IDIR, "Y_*.npy")))

print("IDIR:", IDIR)
print("shards X:", len(X_files))
print("shards Y:", len(Y_files))
print("Ejemplo X:", X_files[:3])
print("Ejemplo Y:", Y_files[:3])

if len(X_files) == 0 or len(Y_files) == 0:
    raise FileNotFoundError(f"No se encontraron shards en {IDIR}")

print("shards:", len(X_files))

class ShardedIntentDataset(Dataset):
    def __init__(self, X_files, Y_files, max_per_shard=None, seed=123):
        self.samples = []
        rng = np.random.default_rng(seed)

        for xf, yf in zip(X_files, Y_files):
            X = np.load(xf, mmap_mode="r")
            Y = np.load(yf, mmap_mode="r")
            n = len(X)

            idx = np.arange(n)
            if max_per_shard is not None and n > max_per_shard:
                idx = rng.choice(idx, size=max_per_shard, replace=False)

            for i in idx:
                self.samples.append((xf, yf, int(i)))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        xf, yf, i = self.samples[idx]
        X = np.load(xf, mmap_mode="r")
        Y = np.load(yf, mmap_mode="r")
        x = torch.tensor(X[i], dtype=torch.float32)   # (1, T)
        y = torch.tensor([Y[i]], dtype=torch.float32) # (1,)
        return x, y

def split_files(files, frac_val=0.15, seed=123):
    idx = np.arange(len(files))
    rng = np.random.default_rng(seed)
    rng.shuffle(idx)

    n_val = max(1, int(len(files) * frac_val))
    val_idx = idx[:n_val]
    tr_idx = idx[n_val:]

    return tr_idx, val_idx

def binary_metrics_from_probs(y_true, y_prob, thr=0.5):
    y_true = np.asarray(y_true).astype(np.int32)
    y_prob = np.asarray(y_prob).astype(np.float32)
    y_pred = (y_prob >= thr).astype(np.int32)

    tp = int(((y_pred == 1) & (y_true == 1)).sum())
    tn = int(((y_pred == 0) & (y_true == 0)).sum())
    fp = int(((y_pred == 1) & (y_true == 0)).sum())
    fn = int(((y_pred == 0) & (y_true == 1)).sum())

    acc = (tp + tn) / max(len(y_true), 1)
    prec = tp / max(tp + fp, 1)
    rec = tp / max(tp + fn, 1)
    f1 = 2 * prec * rec / max(prec + rec, 1e-8)

    return {
        "acc": acc,
        "precision": prec,
        "recall": rec,
        "f1": f1,
        "tp": tp,
        "tn": tn,
        "fp": fp,
        "fn": fn
    }

def roc_auc_fast(y_true, y_score):
    y_true = np.asarray(y_true).astype(np.int32)
    y_score = np.asarray(y_score).astype(np.float64)

    order = np.argsort(y_score)
    y_true = y_true[order]

    n1 = y_true.sum()
    n0 = len(y_true) - n1
    if n0 == 0 or n1 == 0:
        return float("nan")

    ranks = np.arange(1, len(y_true) + 1)
    sum_ranks_pos = ranks[y_true == 1].sum()
    auc = (sum_ranks_pos - n1 * (n1 + 1) / 2) / (n0 * n1)
    return float(auc)
# Out:
# IDIR: /kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset
# shards X: 57
# shards Y: 57
# Ejemplo X: ['/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0000.npy', '/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0001.npy', '/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/X_0002.npy']
# Ejemplo Y: ['/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0000.npy', '/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0001.npy', '/kaggle/input/datasets/jorgeoc/prepared-myoware-v2/prepared_myoware_v2/intent_dataset/Y_0002.npy']
# shards: 57

# %%
# =========================
# CELDA 2: Modelo TCN
# =========================
class TCNBlock(nn.Module):
    def __init__(self, in_ch, out_ch, k=5, dilation=1, drop=0.1):
        super().__init__()
        pad = (k - 1) * dilation // 2
        self.conv1 = nn.Conv1d(in_ch, out_ch, k, padding=pad, dilation=dilation)
        self.bn1 = nn.BatchNorm1d(out_ch)
        self.conv2 = nn.Conv1d(out_ch, out_ch, k, padding=pad, dilation=dilation)
        self.bn2 = nn.BatchNorm1d(out_ch)
        self.act = nn.ReLU()
        self.drop = nn.Dropout(drop)
        self.skip = nn.Conv1d(in_ch, out_ch, 1) if in_ch != out_ch else nn.Identity()

    def forward(self, x):
        s = self.skip(x)
        x = self.drop(self.act(self.bn1(self.conv1(x))))
        x = self.drop(self.act(self.bn2(self.conv2(x))))
        return self.act(x + s)

class IntentTCN(nn.Module):
    def __init__(self):
        super().__init__()
        self.stem = nn.Sequential(
            nn.Conv1d(1, 16, 7, padding=3),
            nn.BatchNorm1d(16),
            nn.ReLU(),
        )
        self.tcn = nn.Sequential(
            TCNBlock(16, 16, dilation=1, drop=0.10),
            TCNBlock(16, 32, dilation=2, drop=0.10),
            TCNBlock(32, 32, dilation=4, drop=0.10),
        )
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.head = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Dropout(0.10),
            nn.Linear(32, 1),
        )

    def forward(self, x):
        x = self.stem(x)
        x = self.tcn(x)
        x = self.pool(x)
        return self.head(x)

# %%
# =========================
# CELDA 3: Entrenamiento
# =========================
idx_tr, idx_val = split_files(X_files, frac_val=0.15, seed=SEED)

X_train = [X_files[i] for i in idx_tr]
Y_train = [Y_files[i] for i in idx_tr]
X_val   = [X_files[i] for i in idx_val]
Y_val   = [Y_files[i] for i in idx_val]

train_ds = ShardedIntentDataset(X_train, Y_train, max_per_shard=4000, seed=1)
val_ds   = ShardedIntentDataset(X_val, Y_val, max_per_shard=4000, seed=2)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True, num_workers=0)
val_loader   = DataLoader(val_ds, batch_size=256, shuffle=False, num_workers=0)

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)

model = IntentTCN().to(device)


# manejar desbalance
y_pos_frac = []
for yf in Y_train:
    y_pos_frac.append(np.load(yf, mmap_mode="r").mean())

approx_pos = float(np.mean(y_pos_frac))
pos_weight_value = (1.0 - approx_pos) / max(approx_pos, 1e-6)
pos_weight = torch.tensor([pos_weight_value], dtype=torch.float32, device=device)

print("approx_pos:", approx_pos, "pos_weight:", pos_weight.item())

criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)

@torch.no_grad()
def evaluate(loader):
    model.eval()
    losses, ys, ps = [], [], []

    for x, y in loader:
        x = x.to(device)
        y = y.to(device)

        logits = model(x)
        loss = criterion(logits, y)
        p = torch.sigmoid(logits)

        losses.append(loss.item() * x.size(0))
        ys.append(y.cpu().numpy().reshape(-1))
        ps.append(p.cpu().numpy().reshape(-1))

    ys = np.concatenate(ys)
    ps = np.concatenate(ps)
    loss = np.sum(losses) / max(len(ys), 1)
    mets = binary_metrics_from_probs(ys, ps, thr=0.5)
    mets["auc"] = roc_auc_fast(ys, ps)
    mets["loss"] = loss
    return mets, ys, ps

history = {
    "train_loss": [], "val_loss": [],
    "val_acc": [], "val_f1": [], "val_auc": []
}

best_state = None
best_score = -1
patience = 5
bad_epochs = 0
EPOCHS = 25

for ep in range(1, EPOCHS + 1):
    model.train()
    t0 = time.time()
    train_loss_sum = 0.0
    n_seen = 0

    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        train_loss_sum += loss.item() * x.size(0)
        n_seen += x.size(0)

    train_loss = train_loss_sum / max(n_seen, 1)
    val_mets, yv, pv = evaluate(val_loader)

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_mets["loss"])
    history["val_acc"].append(val_mets["acc"])
    history["val_f1"].append(val_mets["f1"])
    history["val_auc"].append(val_mets["auc"])

    score = 0.6 * val_mets["f1"] + 0.4 * val_mets["auc"]

    print(
        f"Epoch {ep:02d} | "
        f"train_loss={train_loss:.4f} | val_loss={val_mets['loss']:.4f} | "
        f"acc={val_mets['acc']:.4f} | f1={val_mets['f1']:.4f} | auc={val_mets['auc']:.4f} | "
        f"prec={val_mets['precision']:.4f} | rec={val_mets['recall']:.4f} | "
        f"time={time.time()-t0:.1f}s"
    )

    if score > best_score:
        best_score = score
        best_state = copy.deepcopy(model.state_dict())
        bad_epochs = 0
    else:
        bad_epochs += 1
        if bad_epochs >= patience:
            print("Early stopping.")
            break

model.load_state_dict(best_state)
torch.save(model.state_dict(), "/kaggle/working/intent_binary_best.pt")
print("Guardado: /kaggle/working/intent_binary_best.pt")
# Out:
# device: cuda
# approx_pos: 0.5573095679283142 pos_weight: 0.794334888458252
# Epoch 01 | train_loss=0.4034 | val_loss=0.4209 | acc=0.7900 | f1=0.7777 | auc=0.8434 | prec=0.8355 | rec=0.7275 | time=897.5s
# Epoch 02 | train_loss=0.3971 | val_loss=0.4115 | acc=0.7910 | f1=0.7706 | auc=0.8462 | prec=0.8649 | rec=0.6948 | time=903.4s
# Epoch 03 | train_loss=0.3950 | val_loss=0.4081 | acc=0.7892 | f1=0.7678 | auc=0.8513 | prec=0.8653 | rec=0.6900 | time=874.4s
# Epoch 04 | train_loss=0.3931 | val_loss=0.4026 | acc=0.7920 | f1=0.7716 | auc=0.8552 | prec=0.8664 | rec=0.6955 | time=818.7s
# Epoch 05 | train_loss=0.3915 | val_loss=0.3999 | acc=0.7953 | f1=0.7773 | auc=0.8557 | prec=0.8630 | rec=0.7070 | time=856.3s
# Epoch 06 | train_loss=0.3900 | val_loss=0.3999 | acc=0.7958 | f1=0.7785 | auc=0.8560 | prec=0.8613 | rec=0.7102 | time=806.3s
# Epoch 07 | train_loss=0.3890 | val_loss=0.4052 | acc=0.7898 | f1=0.7626 | auc=0.8562 | prec=0.8878 | rec=0.6684 | time=848.1s
# Epoch 08 | train_loss=0.3891 | val_loss=0.3961 | acc=0.7993 | f1=0.7804 | auc=0.8592 | prec=0.8720 | rec=0.7063 | time=815.2s
# Epoch 09 | train_loss=0.3883 | val_loss=0.3959 | acc=0.7997 | f1=0.7826 | auc=0.8604 | prec=0.8664 | rec=0.7136 | time=805.2s
# Epoch 10 | train_loss=0.3875 | val_loss=0.3974 | acc=0.7928 | f1=0.7664 | auc=0.8574 | prec=0.8900 | rec=0.6729 | time=854.4s
# Epoch 11 | train_loss=0.3871 | val_loss=0.3983 | acc=0.7989 | f1=0.7825 | auc=0.8578 | prec=0.8624 | rec=0.7161 | time=821.7s
# Epoch 12 | train_loss=0.3868 | val_loss=0.3976 | acc=0.8007 | f1=0.7856 | auc=0.8598 | prec=0.8601 | rec=0.7229 | time=882.4s
# Epoch 13 | train_loss=0.3864 | val_loss=0.3965 | acc=0.7987 | f1=0.7802 | auc=0.8570 | prec=0.8695 | rec=0.7076 | time=823.7s
# Epoch 14 | train_loss=0.3863 | val_loss=0.3964 | acc=0.7993 | f1=0.7816 | auc=0.8600 | prec=0.8677 | rec=0.7111 | time=819.5s
# Epoch 15 | train_loss=0.3858 | val_loss=0.3986 | acc=0.8007 | f1=0.7844 | auc=0.8600 | prec=0.8646 | rec=0.7179 | time=848.8s
# Epoch 16 | train_loss=0.3856 | val_loss=0.3919 | acc=0.8004 | f1=0.7805 | auc=0.8601 | prec=0.8777 | rec=0.7027 | time=806.9s
# Epoch 17 | train_loss=0.3850 | val_loss=0.3931 | acc=0.8006 | f1=0.7836 | auc=0.8604 | prec=0.8675 | rec=0.7144 | time=808.8s
# Early stopping.
# Guardado: /kaggle/working/intent_binary_best.pt

# %%
# =========================
# CELDA 4: Gráficas
# =========================
val_mets, yv, pv = evaluate(val_loader)
print("Métricas finales val:", val_mets)

plt.figure(figsize=(8,4))
plt.plot(history["train_loss"], label="train_loss")
plt.plot(history["val_loss"], label="val_loss")
plt.title("Intent - loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,4))
plt.plot(history["val_f1"], label="val_f1")
plt.plot(history["val_auc"], label="val_auc")
plt.plot(history["val_acc"], label="val_acc")
plt.title("Intent - métricas")
plt.legend()
plt.show()

cm = val_mets["tp"], val_mets["tn"], val_mets["fp"], val_mets["fn"]
print("TP, TN, FP, FN =", cm)

yhat = (pv >= 0.5).astype(int)
idx_pos = np.where(yhat == 1)[0][:3]
idx_neg = np.where(yhat == 0)[0][:3]

# visualizar ejemplos
all_x = []
for x, y in val_loader:
    all_x.append(x.numpy())
all_x = np.concatenate(all_x, axis=0)

for i in list(idx_pos) + list(idx_neg):
    plt.figure(figsize=(10,3))
    plt.plot(all_x[i,0])
    plt.title(f"Ejemplo val idx={i} | y_true={yv[i]} | p={pv[i]:.3f}")
    plt.show()
# Out:
# Métricas finales val: {'acc': 0.80065625, 'precision': 0.8601398601398601, 'recall': 0.7229027468448403, 'f1': 0.7855726242898919, 'tp': 11685, 'tn': 13936, 'fp': 1900, 'fn': 4479, 'auc': 0.8598102674099698, 'loss': np.float64(0.39758200907707214)}
# TP, TN, FP, FN = (11685, 13936, 1900, 4479)
